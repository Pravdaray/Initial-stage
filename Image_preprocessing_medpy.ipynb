# %%
import os
import sys
import numpy as np
from medpy.io import *
from medpy.filter import *
import matplotlib.pyplot as plt

# %%
image_data, image_header = load('./Documents/LIVER-SLIVER_Challenge/test/liver-orig001.mhd')

# %%
image_data.shape
image_data.dtype
# Out:
# dtype('int16')

# %%
header.get_pixel_spacing(image_header)
#print image_data
image_data[image_data > image_data.mean()] = image_data.max()
print image_data
plt.show()
# Out:
# [[[-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   ...,
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]]
#
#  [[-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   ...,
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]]
#
#  [[-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   ...,
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]]
#
#  ...,
#  [[-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
# ...

# %%
threshold = otsu(image_data)
print image_data
print np.max(image_data)
# Out:
# [[[-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   ...,
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]]
#
#  [[-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   ...,
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]]
#
#  [[-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   ...,
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]]
#
#  ...,
#  [[-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
# ...

# %%
print image_data
# Out:
# [[[-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   ...,
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]]
#
#  [[-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   ...,
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]]
#
#  [[-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   ...,
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]]
#
#  ...,
#  [[-1024 -1024 -1024 ..., -1024 -1024 -1024]
#   [-1024 -1024 -1024 ..., -1024 -1024 -1024]
# ...

# %%
print np.max(image_data)
# Out:
# 3071
